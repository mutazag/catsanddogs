# %% [markdown]
# # Tabular Datesets
#
# Explore the use of the Azure ML Tabular Dataset as a pandas DataFrame.

# %%
import pandas as pd


from azureml.core import Workspace
from azureml.core import Datastore, Dataset

# %% [markdown]
# retrieve the dataset from the Azure ML service by name using:
#
# ```python
#     Dataset.get_by_name(workspace, <datasetname>)
# ```

# %%
ws = Workspace.from_config()
ds = Dataset.get_by_name(ws, 'diabetes_v1')
print(type(ds))
# Out:
# <class 'azureml.data.tabular_dataset.TabularDataset'>

# %% [markdown]
# Convert v1 tabular data set to a pandas DataFrame using:
#
# ```python
#     dataset.to_pandas_dataframe()
# ```

# %%
df = ds.to_pandas_dataframe()
df.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
# plot the distribution of the target variable

import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x='Y', data=df, palette='hls')
plt.show()

# %%
sns.distplot(df['AGE'])
plt.show()
# Out:
# /tmp/ipykernel_82258/535920156.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['AGE'])
